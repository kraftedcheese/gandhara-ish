# %%
import pandas as pd
import numpy as np 
import re

# %%
pd.set_option('display.max_rows', 500)

# %%
buddha = pd.read_csv("buddha.csv")
greek = pd.read_csv("greek.csv")
gandhara = pd.read_csv("gandhara.csv")

# %%
# Add types to each df
buddha["type"] = "Buddhist"
greek["type"] = "Greek"
gandhara["type"] = "Gandharan"

# %%
print(buddha["Production date"].isna().values.any())
print(greek["Production date"].isna().values.any())
print(gandhara["Production date"].isna().values.any())
# Out:
# False
# False
# True

# %%
buddha["Production date"].value_counts()
# Out:
# 3rdC                                                      43
# 2ndC                                                      32
# 2ndC-3rdC                                                 31
# 4thC-7thC                                                 12
# 6thC                                                      11
# 4thC-5thC                                                 10
# 7thC-8thC                                                 10
# 5thC                                                       9
# 5thC-6thC                                                  8
# 6thC-7thC                                                  7
# 1stC                                                       6
# 7thC-8thC (circa)                                          6
# 3rdC-7thC (circa)                                          5
# 6thC (Whitfield 1985); 7thC-8thC (Ghose 2004)              4
# 7thC                                                       4
# 6thC-9thC                                                  2
# 1stC (circa)                                               2
# 1stC-4thC                                                  2
# 200-240 (circa)                                            2
# 6thC-8thC                                                  2
# 2ndC BC (circa)                                            1
# 7thC (first half)                                          1
# 7thC (late)                                                1
# 6thC (second quarter)                                      1
# 3rdC-5thC (circa)                                          1
# 520-530 (circa)                                            1
# 2ndC (about)                                               1
# 2ndC-3rdC (circa)                                          1
# 1stC BC (obverse face); 3rdC (reverse face)                1
# 3rdC-4thC                                                  1
# 6thC(late)                                                 1
# 384                                                        1
# 1stC BC-2ndC BC (obverse face); 200-240 (reverse face)     1
# 265-316                                                    1
# 6thC-7thC (circa)                                          1
# 1stC-3rdC                                                  1
# 589-906 (circa)                                            1
# 100 (circa; the original object); 20thC (replica)          1
# 1stC BC                                                    1
# 552                                                        1
# 2ndC BC                                                    1
# 2ndC-4thC (circa)                                          1
# 207-700 (circa)                                            1
# 1stC-2ndC                                                  1
# 3rdC-7thC                                                  1
# 18061811 (circa, design)                                   1
# 7thC-8thC (or later)                                       1
# 3rdC-6thC (circa)                                          1
# 500-700                                                    1
# 3rdC-8thC (circa)                                          1
# 4000BC-3000BC                                              1
# 200-240                                                    1
# 4thC                                                       1
# 550-577                                                    1
# 3rdC-7thC (?)                                              1
# 6000 BC-3000 BC                                            1
# 2ndC (or earlier)                                          1
# 585 (Dated by inscription)                                 1
# 178 (date given in inscription)                            1
# 584                                                        1
# 3rdC BC-2ndC (circa)                                       1
# 440-451                                                    1
# 4thC-5thC (circa)                                          1
# 1stC-5thC (circa)                                          1
# 6thC (early)                                               1
# 589-618                                                    1
# Name: Production date, dtype: int64

# %%
greek["Production date"].value_counts()
# Out:
# 332BC-250BC                                                    48
# 3rdC BC-2ndC BC                                                44
# 2ndC BC-1stC BC                                                27
# 3rdC BC                                                        22
# 1stC BC-1stC                                                   20
# 2ndC BC                                                        15
# 1stC BC                                                        13
# 300BC (circa)                                                  11
# 3rdC BC - 2ndC BC                                               9
# 4thC BC(late)                                                   9
# 4thC BC                                                         9
# 350 BC - 300 BC                                                 7
# 3rdC BC - 1stC BC                                               7
# 250BC-200BC                                                     6
# 6thC BC - 2ndC BC                                               5
# 3rdC BC-1stC BC                                                 5
# 4thC BC-1stC BC                                                 5
# 300BC-250BC                                                     5
# 3rdC BC(late)-1stC BC(mid)                                      5
# 3rdC BC(late)-2ndC BC                                           5
# 332BC - 200BC                                                   5
# 350BC-300BC                                                     4
# 3rdC BC(late)-2ndC BC(early)                                    4
# 330BC - 200BC                                                   4
# 4thC BC-3rdC BC                                                 4
# 1stC BC - 1stC AD                                               4
# 300BC - 30BC                                                    4
# 2ndC BC (circa)                                                 3
# 300BC-200BC                                                     3
# 2ndC BC-2ndC                                                    3
# 4thC BC(late)-3rdC BC(early)                                    3
# 380 BC - 280 BC (circa)                                         3
# (early)3rdC BC - (early)1stC BC                                 3
# 4thC BC(late)-3rdC BC                                           3
# 3rdC BC (?)                                                     3
# 4thC BC-3rdC BC (circa)                                         3
# 300 BC-50 BC                                                    2
# 500BC - 250BC                                                   2
# 1stC                                                            2
# 2ndC BC(late)-1stC BC(early)                                    2
# 199BC-100BC                                                     2
# 320BC-250BC                                                     2
# 300BC (no later than circa)                                     2
# 4thC BC - 2ndC BC                                               2
# 3rdC BC - (early)1stC BC                                        2
# 2ndC BC-1stC BC (?)                                             2
# 4thC BC-3rdC BC (?)                                             2
# 323BC-31BC                                                      2
# 50 (circa)                                                      2
# 350BC-300BC (circa)                                             2
# 4thC BC (circa)                                                 2
# 600BC-250                                                       2
# 2ndC                                                            2
# 250BC-150BC                                                     2
# 330BC-200BC (?)                                                 2
# 3rdC BC(early)                                                  2
# 1stC BC (circa)                                                 2
# 300BC - 200BC                                                   2
# 2ndC BC - 1stC BC                                               2
# 300 BC - 100 BC                                                 2
# 325BC-300BC                                                     2
# 1stC(late)-2ndC(early)                                          2
# 330BC-250BC                                                     2
# 250BC-200BC (or later)                                          2
# 300BC-100BC                                                     2
# 330BC - 250BC                                                   2
# 200BC-100                                                       1
# 400 BC-100 BC                                                   1
# 3rdC BC ((?))                                                   1
# 340BC-300BC                                                     1
# 250BC - 200BC (probably)                                        1
# 120BC-30BC                                                      1
# 300BC (no later than)                                           1
# (late)4thC BC- (late)3rdC BC                                    1
# 5thC BC-3rdC BC (circa)                                         1
# 2ndC BC-1stC BC (uncertain)                                     1
# 2ndC BC; late 2nd century BC - early 1st century BC             1
# 330BC-100BC                                                     1
# 4thC BC - 2ndC AD                                               1
# 4thC BC(late) (possibly)                                        1
# 150 BC-30 BC                                                    1
# 3rdC BC(late)-2ndC BC(late)                                     1
# 200BC-150BC (circa)                                             1
# 200BC - 30BC                                                    1
# 6thC BC - 1stC BC                                               1
# 1stC BC-1stC AD                                                 1
# 230BC-200BC (circa)                                             1
# 400BC-200BC                                                     1
# 1stC(late)BC-1stC                                               1
# 300BC-201BC                                                     1
# 3rdC BC -2ndC BC                                                1
# 400BC-300BC (circa)                                             1
# 400 BC-200 BC                                                   1
# 50BC-30BC (circa)                                               1
# 2ndC BC (or later, though earlier date cannot be ruled out)     1
# 305BC–30BC                                                      1
# 1stC(late) BC-1stC(early) (circa)                               1
# 323 BC - 246 BC (likely)                                        1
# 250BC-150BC (circa)                                             1
# 200BC-160BC                                                     1
# 330BC -200BC                                                    1
# 300 BC-250 BC                                                   1
# 1stC BC-2ndC AD                                                 1
# 2ndC BC(late)-1stC                                              1
# 100 BC (about)                                                  1
# 1stC BC-3rdC                                                    1
# 1stC BC-3rdC (circa)                                            1
# 300BC (not long after)                                          1
# 100 BC-50 BC (circa)                                            1
# 1stC BC (inscription on the face of the slab)                   1
# 3rdC BC (not earlier than)                                      1
# 330BC-200BC                                                     1
# 2ndC BC; 200BC-150BC                                            1
# 332BC-30BC                                                      1
# 41BC                                                            1
# 450BC - 300BC                                                   1
# 350BC-300BC (?)                                                 1
# 6thC BC-6thC                                                    1
# 3rdC BC(mid)                                                    1
# 100BC-75BC                                                      1
# 300BC-101BC                                                     1
# 3rdc BC - 1stC BC                                               1
# 3rdC BC(late) (not earlier than)                                1
# 200 BC-150 BC (circa)                                           1
# 199BC-101BC (?)                                                 1
# 300BC - 100BC                                                   1
# 4thC BC - 1stC BC (?); 1stC AD - 7thC AD (?)                    1
# (late)4thC BC - (late)3rdC BC                                   1
# 50 BC - AD 50 (around)                                          1
# 200BC-100BC                                                     1
# 250BC (circa)                                                   1
# 40BC (circa)                                                    1
# 250BC (circa, or even later)                                    1
# 1stC-2ndC                                                       1
# 323BC-30BC                                                      1
# 332BC-31BC                                                      1
# 100 BC-100 AD                                                   1
# 4thC BC-1stC                                                    1
# 100BC-50                                                        1
# 275BC (not later than)                                          1
# 240 BC - 200 BC; 3rd century BC                                 1
# 3rdC BC-1stC(mid) BC                                            1
# 3rdC BC (For inscription 410B)                                  1
# 1stC(late)                                                      1
# 3rdC BC(late)                                                   1
# 350 BC-300BC                                                    1
# 1stC ((head late fourth century BC))                            1
# 3rdC BC(mid)-3rdC BC(late)                                      1
# 400 BC-300 BC                                                   1
# 330BC-300BC                                                     1
# 4thC BC-2ndC BC (?)                                             1
# 2ndC BC (?)                                                     1
# 4thC BC (late) - 3rdC BC (late) (possibly)                      1
# 3rdC BC - (mid)1stC BC                                          1
# 286BC-246BC                                                     1
# 250 BC-100 BC                                                   1
# 300BC-150BC (difficult to determine)                            1
# 240BC (circa)                                                   1
# 525BC-31BC                                                      1
# 600BC-31BC                                                      1
# 300 BC - 200 BC                                                 1
# 399BC-300BC                                                     1
# 2ndC BC(late)-1stC BC                                           1
# 3rdC BC-2ndC; 1stC                                              1
# 50 BC (around)                                                  1
# 3rdC BC-2ndC                                                    1
# 300 BC-200 BC                                                   1
# (late)3rdC BC - (early)1stC BC (date of context)                1
# 2ndC BC-1stC BC(early)                                          1
# 5thC BC-4thC BC                                                 1
# 300BC-200BC (circa)                                             1
# 3rdC BC-(early)1stC BC                                          1
# (late)2nd BC- (early)1st BC                                     1
# 340BC-150BC                                                     1
# 2ndC BC - 1stC AD                                               1
# 150-200                                                         1
# 2ndC BC (late)                                                  1
# 300BC-100AD                                                     1
# 4thC BC (possibly)                                              1
# 400BC-275BC                                                     1
# 350 BC -300BC                                                   1
# 100 BC - 100 AD                                                 1
# 246BC-221BC                                                     1
# 330BC - 150BC                                                   1
# 3rdC BC - 1stC BC (?); 1stC AD (?)                              1
# 3rdC BC -1stC BC                                                1
# 6thC BC-4thC BC                                                 1
# 350BC-250BC                                                     1
# 100 BC - AD 50                                                  1
# 4thC BC-2ndC BC                                                 1
# 2ndC BC (probably)                                              1
# 350BC-200BC (c.)                                                1
# 360 BC - 300 BC                                                 1
# 300BC-250BC (circa)                                             1
# 3rdC(late) BC-1stC BC                                           1
# 1stC AD-2ndC AD; 2ndC BC-1stC BC                                1
# 200 BC - AD 100                                                 1
# 250 BC-200 BC                                                   1
# 4thC BC(late); 332BC-323BC                                      1
# 50 BC - AD 50                                                   1
# 100-150 (circa)                                                 1
# 5thC BC-1stC BC (?)                                             1
# 3rdC BC (Late (?))                                              1
# (late)3rdC BC-(early)1stC BC                                    1
# 2ndC(late) BC-1stC BC                                           1
# 332BC - 200BC (possibly later)                                  1
# 3rdC(late) BC-2ndC BC (circa)                                   1
# 150BC-50BC                                                      1
# 400BC-100BC                                                     1
# 220BC-180BC                                                     1
# (mid)3rdC BC - (late)2ndC BC                                    1
# 25BC-50 (circa)                                                 1
# 250BC-200BC (circa)                                             1
# 1stC (perhaps as late as)                                       1
# 200BC-100BC (circa)                                             1
# 2ndC BC (later)                                                 1
# Name: Production date, dtype: int64

# %%
gandhara["Production date"].value_counts()
gandhara["Production date"].dropna(inplace=True)

# %%
def get_year(date_str):
    arr = [x.strip() for x in date_str.split("-")]
    BC_multiplier = 1
    if "BC" in arr[0]:
        BC_multiplier = -1
    number_groups = re.findall(r'\d+', arr[0])
    if len(number_groups[0]) == 1:
        year = int(number_groups[0]) * 100
    else:
        year = int(number_groups[0])
    return year * BC_multiplier

# %%
get_year("50 BC - AD 50")
# Out:
# -50

# %%
buddha["date"] = buddha["Production date"].apply(get_year)
greek["date"] = greek["Production date"].apply(get_year)
gandhara["date"] = gandhara["Production date"].apply(get_year)

# %%
all = pd.concat([buddha, greek, gandhara])

# %%
all["filename"] = all["id"] + ".jpg"

# %%
all["filename"]
# Out:
# 0      18870717144.jpg
# 1       1892080111.jpg
# 2        189011161.jpg
# 3       1902100217.jpg
# 4       1880070940.jpg
#             ...
# 191         188054.jpg
# 192         188041.jpg
# 193      191405021.jpg
# 194        1880227.jpg
# 195     1925061920.jpg
# Name: filename, Length: 993, dtype: object

# %%
all_selected = all[['filename', 'id', 'type', 'date']]

# %%
measurements = pd.read_csv("measurements.txt", sep="\t")

# %%
together = pd.merge(all_selected, measurements, on="filename")

# %%
together
# Out:
#             filename           id       type   date  imageID  \
# 0    18870717144.jpg  18870717144   Buddhist -300.0      403
# 1     1892080111.jpg   1892080111   Buddhist  200.0      445
# 2      189011161.jpg    189011161   Buddhist  384.0      441
# 3     1902100217.jpg   1902100217   Buddhist  200.0      506
# 4     1880070940.jpg   1880070940   Buddhist  300.0      223
# ..               ...          ...        ...    ...      ...
# 988       188054.jpg       188054  Gandharan  200.0      334
# 989       188041.jpg       188041  Gandharan  200.0      330
# 990    191405021.jpg    191405021  Gandharan  200.0      609
# 991      1880227.jpg      1880227  Gandharan  200.0      310
# 992   1925061920.jpg   1925061920  Gandharan  600.0      639
#
#      brightness_median  brightness_stdev  saturation_median  saturation_stdev  \
# 0                  224           80.4079                  2           54.1441
# 1                  218           63.1146                 11           17.0227
# 2                  130           55.8103                 32           25.6474
# 3                  215           63.9945                  4            8.9645
# 4                  139           57.0025                 72           25.9706
# ..                 ...               ...                ...               ...
# 988                170           63.5285                 25           27.4960
# 989                203           56.9162                  7           40.3854
# 990                244           71.3581                  0           12.9680
# 991                149           57.8868                  3           15.1840
# 992                132           27.6378                 81           23.1721
#
#      hue_median  hue_stdev
# 0            28    70.8063
# 1            26     4.4934
# 2           191    77.5272
# 3           177    91.6795
# 4             9    34.9751
# ..          ...        ...
# 988         228   101.8552
# 989          35    27.8027
# 990           0    34.1007
# 991          42    19.8062
# 992          26    39.0993
#
# [993 rows x 11 columns]

# %%
together.drop(index=together[together["date"].max()])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\Python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 18061811.0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-352c3de15530> in <module>
# ----> 1 together.drop(index=together[together["date"].max()])
#
# C:\Program Files\Python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# C:\Program Files\Python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 18061811

# %%
together.to_csv("imageplot_all/metadata.txt", sep="\t", index=False)

# %%
together.max()
# Out:
# filename             greek94.jpg
# id                       greek94
# type                       Greek
# date                 1.80618e+07
# imageID                      994
# brightness_median            255
# brightness_stdev         99.7172
# saturation_median            230
# saturation_stdev         104.061
# hue_median                   244
# hue_stdev                118.297
# dtype: object

# %%
together.min()
# Out:
# filename             12745.jpg
# id                       12745
# type                  Buddhist
# date                     -6000
# imageID                      1
# brightness_median            0
# brightness_stdev        4.8688
# saturation_median            0
# saturation_stdev        0.7659
# hue_median                   0
# hue_stdev                1.149
# dtype: object
